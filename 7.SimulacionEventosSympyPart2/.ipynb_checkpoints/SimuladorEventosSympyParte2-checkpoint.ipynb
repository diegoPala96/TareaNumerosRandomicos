# %% [markdown]
# Presentado por: Diego Quisi
#
# # Entornos de soporte al desarrollo de simulaciones: Simpy - Parte 2
#
#
# ## Generacion de graficar de atencion.
#
# En base a la simulacion anterior generar una grafica de los autos atendidos.

# %%
import simpy
import random
import matplotlib.pyplot as pp

# %matplotlib inline

# Maximo de vehiculos que puede recibir el negocio
MAX_VEHICULOS = 57
# Total de maquinas de lavado con que cuenta el negocio
NUM_MAQUINAS = 3
# Tiempo que tarda en lavarse un vehiculo (minutos)
TIEMPO_LAVADO = 10 
# Intervalo de tiempo en que llegan vehiculos (minutos)
INTERVALO_LLEGADA = 3
# Tiempo de simulación
TIEMPO_SIMULACION = 27

# Creamos un diccionario para almacenar las horas en que se lavan los vehiculos
tiempo={}

class Lavanderia(object):
    
    def __init__(self, environment, num_maquinas, tiempo_lavado):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        # Variable para el tiempo de lavado
        self.tiempo_lavado = tiempo_lavado
        
    def lavar_vehiculo(self, vehiculo):
        # Este metodo representa el proceso de lavado del vehículo.
        # Se ingresa el vehículo y se lava
        
        # Simulamos el tiempo que tarda en lavarse el vehiculo
        # Es importante notar que la instruccion "yield" es distinta de "sleep"
        # ya que esta ultima bloquea el hilo de ejecucion durante 't' unidades de tiempo,
        # mientras que 'yield' no bloquea el hilo de ejecucion, solo lo suspende mientras
        # el evento de 'lavado' se realice
        yield self.env.timeout(random.randint(TIEMPO_LAVADO-5, TIEMPO_LAVADO+5))
        
        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90
        print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))
        
    
def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('Llega vehiculo: %s a la hora %.2f.' % (nombre, env.now))
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    with lavanderia.maquinas.request() as maquina:
        # Ocupamos la maquina de lavado
        yield maquina
        # Indicamos que vehiculo entra a la lavanderia
        print('Entra vehiculo a lavarse: %s a la hora %.2f.' % (nombre, env.now))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehiculo [%s] lavado a las %.2f.' % (nombre, env.now))

       
        tiempo[nombre]=env.now
        
    
def ejecutar_simulacion(env, num_maquinas, tiempo_lavado, intervalo):
    lavanderia=Lavanderia(env, num_maquinas, tiempo_lavado)
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(5):
        env.process(llegada_vehiculo(env, 'Vehiculo-%d'%(i+1),lavanderia))
    
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+3))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        env.process(llegada_vehiculo(env,'Vehiculo-%d'%(i+1),lavanderia))

print('Lavanderia UPS')

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS, TIEMPO_LAVADO, INTERVALO_LLEGADA))

# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)


print("Diccionario timepo :")
print(tiempo)
# Out:
# Lavanderia UPS
# Llega vehiculo: Vehiculo-1 a la hora 0.00.
# Llega vehiculo: Vehiculo-2 a la hora 0.00.
# Llega vehiculo: Vehiculo-3 a la hora 0.00.
# Llega vehiculo: Vehiculo-4 a la hora 0.00.
# Llega vehiculo: Vehiculo-5 a la hora 0.00.
# Entra vehiculo a lavarse: Vehiculo-1 a la hora 0.00.
# Entra vehiculo a lavarse: Vehiculo-2 a la hora 0.00.
# Entra vehiculo a lavarse: Vehiculo-3 a la hora 0.00.
# Llega vehiculo: Vehiculo-6 a la hora 6.00.
# Removido  {81%} suciedad vehiculo => Vehiculo-1
# Removido  {42%} suciedad vehiculo => Vehiculo-2
# Removido  {45%} suciedad vehiculo => Vehiculo-3
# Llega vehiculo: Vehiculo-7 a la hora 12.00.
# Vehiculo [Vehiculo-1] lavado a las 12.00.
# Vehiculo [Vehiculo-2] lavado a las 12.00.
# Vehiculo [Vehiculo-3] lavado a las 12.00.
# Entra vehiculo a lavarse: Vehiculo-4 a la hora 12.00.
# Entra vehiculo a lavarse: Vehiculo-5 a la hora 12.00.
# Entra vehiculo a lavarse: Vehiculo-6 a la hora 12.00.
# Llega vehiculo: Vehiculo-8 a la hora 16.00.
# Llega vehiculo: Vehiculo-9 a la hora 16.00.
# Llega vehiculo: Vehiculo-10 a la hora 16.00.
# Removido  {87%} suciedad vehiculo => Vehiculo-6
# Vehiculo [Vehiculo-6] lavado a las 17.00.
# Entra vehiculo a lavarse: Vehiculo-7 a la hora 17.00.
# Llega vehiculo: Vehiculo-11 a la hora 22.00.
# Removido  {40%} suciedad vehiculo => Vehiculo-4
# Vehiculo [Vehiculo-4] lavado a las 24.00.
# Entra vehiculo a lavarse: Vehiculo-8 a la hora 24.00.
# Removido  {67%} suciedad vehiculo => Vehiculo-5
# Llega vehiculo: Vehiculo-12 a la hora 25.00.
# Vehiculo [Vehiculo-5] lavado a las 25.00.
# Entra vehiculo a lavarse: Vehiculo-9 a la hora 25.00.
# Diccionario timepo :
# {'Vehiculo-1': 12, 'Vehiculo-2': 12, 'Vehiculo-3': 12, 'Vehiculo-6': 17, 'Vehiculo-4': 24, 'Vehiculo-5': 25}

# %%
# Generamos la grafica
datos=sorted(tiempo.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
pp.title("Vehiculos Atenndidos X Tiempo")
pp.grid(True) #Generamos una cuadricula
pp.show() #Mostramos el grafico

# %% [markdown]
# ## Paremetrizando la simulacion
#
# * Considerar 3 tipos de vehículos con 3 diferentes tiempos de lavado:
#     * Bus: 20 minutos
#     * Automóvil: 7 minutos
#     * Furgoneta: 12 minutos
# * Considere que a partir de la entrada del vehículo para ser lavado, deberán tomarse en cuenta los siguientes tiempos correspondientes al proceso de traslado desde la recepción a la máquina de lavado:
#     * Bus: 4 minutos
#     * Automóvil: 1 minuto
#     * Furgoneta: 2 minutos
# * Realice una gráfica de la simulación con 3 máquinas de lavado

# %%
# Maximo de vehiculos que puede recibir el negocio
MAX_VEHICULOS = 57 
# Total de maquinas de lavado con que cuenta el negocio
NUM_MAQUINAS = 3
# Tiempo que tarda en trasladarse un vehiculo (minutos)
TRASLADO_BUS = 4
TRASLADO_AUTOMOVIL= 1
TRASLADO_FURGONETA= 2
# Tiempo que tarda en lavarse un vehiculo (minutos)
TIEMPO_BUS = 20
TIEMPO_AUTOMOVIL= 7
TIEMPO_FURGONETA= 12
# Intervalo de tiempo en que llegan vehiculos (minutos)
INTERVALO_LLEGADA = 10
# Tiempo de simulación
TIEMPO_SIMULACION = 100

# Creamos un diccionario para almacenar las horas en que se lavan los vehiculos
tiempo={}

class Lavanderia(object):
    
    def __init__(self, environment, num_maquinas,tiempo_bus,tiempo_automovil,
                 tiempo_furgoneta,traslado_bus,traslado_automovil,traslado_furgoneta):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        # Variable para el tiempo de lavado
        self.tiempo_bus = tiempo_bus
        self.tiempo_automovil = tiempo_automovil
        self.tiempo_furgoneta = tiempo_furgoneta
        self.traslado_bus = traslado_bus
        self.traslado_automovil = traslado_automovil
        self.traslado_furgoneta = traslado_furgoneta
        
    def lavar_vehiculo(self, vehiculo):
        automotor=vehiculo.split('-')
        if(automotor[0] == 'Bus'):
            yield self.env.timeout(TIEMPO_BUS)
        if(automotor[0] == 'Automovil'):
            yield self.env.timeout(TIEMPO_AUTOMOVIL)
        if(automotor[0] == 'Furgoneta'):
            yield self.env.timeout(TIEMPO_FURGONETA)
        #Solo agregamos al diccionario al momento que termina de lavar el vehiculo.
        k=automotor[0]
        if k in tiempo:
            tiempo[k]=tiempo[k]+1
        else:
            tiempo[k]=1
            
        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90
        print('Removido  {%d%%} suciedad vehiculo => %s ' %(random.randint(30,90), vehiculo))
        
    def trasladar_vehiculo(self, vehiculo):
        automotor=vehiculo.split('-')
        if(automotor[0] == 'Bus'):
            yield self.env.timeout(TRASLADO_BUS)
        if(automotor[0] == 'Automovil'):
            yield self.env.timeout(TRASLADO_AUTOMOVIL)
        if(automotor[0] == 'Furgoneta'):
            yield self.env.timeout(TRASLADO_FURGONETA)
       
    
def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('Llega vehiculo: %s a la hora %.2f.' % (nombre, env.now))
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    with lavanderia.maquinas.request() as maquina:
        # Ocupamos la maquina de lavado
        yield maquina
        #Indicamos que el vehiculo se esta trasladando para ser lavado
        print('Se traslada vehiculo: %s a la hora %.2f.' % (nombre,env.now))
        #Procesamos el traslado del vehiculo
        yield env.process(lavanderia.trasladar_vehiculo(nombre))
        # Indicamos que vehiculo entra a la lavanderia
        print('Entra vehiculo a lavarse: %s a la hora %.2f.' % (nombre, env.now))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehiculo [%s] lavado a las %.2f.' % (nombre, env.now))  
        
def ejecutar_simulacion(env, num_maquinas, tiempo_bus,tiempo_automovil,
                        tiempo_furgoneta,traslado_bus,traslado_automovil,
                        traslado_furgoneta, intervalo):
    lavanderia=Lavanderia(env, num_maquinas, tiempo_bus,tiempo_automovil,
                          tiempo_furgoneta,traslado_bus,traslado_automovil,
                          traslado_furgoneta)
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(2):
        env.process(llegada_vehiculo(env, 'Bus-%d'%(i+1),lavanderia))
        env.process(llegada_vehiculo(env, 'Automovil-%d'%(i+1),lavanderia))
        env.process(llegada_vehiculo(env, 'Furgoneta-%d'%(i+1),lavanderia))
        
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+3))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        rnd = random.randint(1,100)
        if rnd <= 20: # Bus 20%, Furgoneta 30% y Automovil 50%
            env.process(llegada_vehiculo(env,'Bus-%d'%(i+1),lavanderia))
        elif rnd <= 50:
            env.process(llegada_vehiculo(env,'Furgoneta-%d'%(i+1),lavanderia))
        else:
            env.process(llegada_vehiculo(env,'Automovil-%d'%(i+1),lavanderia))

print('Lavanderia UPS')

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS, TIEMPO_BUS,TIEMPO_AUTOMOVIL,
                                TIEMPO_FURGONETA,TRASLADO_BUS,TRASLADO_AUTOMOVIL,
                                TRASLADO_FURGONETA, INTERVALO_LLEGADA))
# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)

# Generamos la grafica
datos=sorted(tiempo.items())
x, y =zip(*datos)
pp.plot(x,y,linewidth=2,color='red')
pp.scatter(x,y,color='blue')
pp.grid(True)
pp.show()
# Out:
# Lavanderia UPS
# Llega vehiculo: Bus-1 a la hora 0.00.
# Llega vehiculo: Automovil-1 a la hora 0.00.
# Llega vehiculo: Furgoneta-1 a la hora 0.00.
# Llega vehiculo: Bus-2 a la hora 0.00.
# Llega vehiculo: Automovil-2 a la hora 0.00.
# Llega vehiculo: Furgoneta-2 a la hora 0.00.
# Se traslada vehiculo: Bus-1 a la hora 0.00.
# Se traslada vehiculo: Automovil-1 a la hora 0.00.
# Se traslada vehiculo: Furgoneta-1 a la hora 0.00.
# Entra vehiculo a lavarse: Automovil-1 a la hora 1.00.
# Entra vehiculo a lavarse: Furgoneta-1 a la hora 2.00.
# Entra vehiculo a lavarse: Bus-1 a la hora 4.00.
# Removido  {32%} suciedad vehiculo => Automovil-1
# Vehiculo [Automovil-1] lavado a las 8.00.
# Se traslada vehiculo: Bus-2 a la hora 8.00.
# Llega vehiculo: Furgoneta-3 a la hora 12.00.
# Entra vehiculo a lavarse: Bus-2 a la hora 12.00.
# Removido  {88%} suciedad vehiculo => Furgoneta-1
# Vehiculo [Furgoneta-1] lavado a las 14.00.
# Se traslada vehiculo: Automovil-2 a la hora 14.00.
# Entra vehiculo a lavarse: Automovil-2 a la hora 15.00.
# Llega vehiculo: Automovil-4 a la hora 22.00.
# Removido  {81%} suciedad vehiculo => Automovil-2
# Vehiculo [Automovil-2] lavado a las 22.00.
# Se traslada vehiculo: Furgoneta-2 a la hora 22.00.
# Removido  {55%} suciedad vehiculo => Bus-1
# Vehiculo [Bus-1] lavado a las 24.00.
# Entra vehiculo a lavarse: Furgoneta-2 a la hora 24.00.
# Se traslada vehiculo: Furgoneta-3 a la hora 24.00.
# Entra vehiculo a lavarse: Furgoneta-3 a la hora 26.00.
# Llega vehiculo: Bus-5 a la hora 29.00.
# Removido  {77%} suciedad vehiculo => Bus-2
# Vehiculo [Bus-2] lavado a las 32.00.
# Se traslada vehiculo: Automovil-4 a la hora 32.00.
# Entra vehiculo a lavarse: Automovil-4 a la hora 33.00.
# Removido  {43%} suciedad vehiculo => Furgoneta-2
# Vehiculo [Furgoneta-2] lavado a las 36.00.
# Se traslada vehiculo: Bus-5 a la hora 36.00.
# Removido  {73%} suciedad vehiculo => Furgoneta-3
# Vehiculo [Furgoneta-3] lavado a las 38.00.
# Removido  {65%} suciedad vehiculo => Automovil-4
# Vehiculo [Automovil-4] lavado a las 40.00.
# Entra vehiculo a lavarse: Bus-5 a la hora 40.00.
# Llega vehiculo: Automovil-6 a la hora 42.00.
# Se traslada vehiculo: Automovil-6 a la hora 42.00.
# Entra vehiculo a lavarse: Automovil-6 a la hora 43.00.
# Removido  {83%} suciedad vehiculo => Automovil-6
# Vehiculo [Automovil-6] lavado a las 50.00.
# Llega vehiculo: Automovil-7 a la hora 53.00.
# Se traslada vehiculo: Automovil-7 a la hora 53.00.
# Entra vehiculo a lavarse: Automovil-7 a la hora 54.00.
# Removido  {53%} suciedad vehiculo => Bus-5
# Vehiculo [Bus-5] lavado a las 60.00.
# Removido  {59%} suciedad vehiculo => Automovil-7
# Vehiculo [Automovil-7] lavado a las 61.00.
# Llega vehiculo: Automovil-8 a la hora 66.00.
# Se traslada vehiculo: Automovil-8 a la hora 66.00.
# Entra vehiculo a lavarse: Automovil-8 a la hora 67.00.
# Llega vehiculo: Automovil-9 a la hora 74.00.
# Removido  {86%} suciedad vehiculo => Automovil-8
# Se traslada vehiculo: Automovil-9 a la hora 74.00.
# Vehiculo [Automovil-8] lavado a las 74.00.
# Entra vehiculo a lavarse: Automovil-9 a la hora 75.00.
# Removido  {76%} suciedad vehiculo => Automovil-9
# Vehiculo [Automovil-9] lavado a las 82.00.
# Llega vehiculo: Bus-10 a la hora 83.00.
# Se traslada vehiculo: Bus-10 a la hora 83.00.
# Entra vehiculo a lavarse: Bus-10 a la hora 87.00.
# Llega vehiculo: Automovil-11 a la hora 93.00.
# Se traslada vehiculo: Automovil-11 a la hora 93.00.
# Entra vehiculo a lavarse: Automovil-11 a la hora 94.00.

# %% [markdown]
# ## Práctica  Sympy 2
#
# En base a la simulacion, generar una simulacion lo mas apegado a la realidad del Covid-19, para ello obtener informacion del numero de consultorios y camas disponibles en un hospital del Ecuador. Parametrizar la simulacion para ingresar el numero de pacientes, el numero de consultorios y el numero de camas y algun otro parametro que considere oportun
#
# Finalmente generar las siguientes metricas :
# - Tiempo de espera promedio para cada sala.
# - Tiempo promedio total que requiere un paciente para ser atendido desde cero.
# - Cuántos pacientes se atendieron.
# - Cuántos pacientes se quedaron sin atender y fallecieron.
#
# Finalmente generar las simulaciones para el pico de atencion de R0 calculado y R0 predecido la siguiente semana.
# - infectados actual 390
# - Media provincia Los Rios 145.5
# - Mediana provincia Los Rios 150.28
# - R0=3.316

# %%
import simpy 
import random
import matplotlib.pyplot as pp
# %matplotlib inline

#PARAMETROS
HOSPITALES=2
TASA_CRECIMIENTO=145
INFECTADOS=390
HOSPITAL_CAMA_A=106 #HOSPITAL MARTIN ICAZA 106 total ocupadas regularmente 71
HOSPITAL_CAMA_B=71 #Hospital Cantonal Sagrado Corazón de Jesús
CONSULTORIO_HOSPITAL_A=5
CONSULTORIO_HOSPITAL_B=3
DIAS_SIMULACION = 20
DIAS_INTERNADO = 10

#Diccionario para almacenar los resultados
persona_recuperadas={}
persona_fallecidas={}

personas_sin_atender=[]

class Hospital(object):
    def __init__(self,env,num_cama,name,num_consultorio):
        self.env=env
        self.num_cama=num_cama
        self.camas=simpy.Resource(env,num_cama)
        self.consultorio=simpy.Resource(env,num_consultorio)
        self.name=name
        #self.tiempo_llegada=tiempo_llegada
        
    def triaje(self,paciente,tipo,tiempo):
        print('consultorio disponible en el hospital ',self.name)
       # tiempo[paciente] = env.now
        tipo_paciente=""
        if(tipo==1):
            tipo_paciente='niño'
            #print('llega niño')
            yield self.env.timeout(random.uniform(0.015, 0.030) ) #tiempo de espera por la sala
           # tiempo_sala1.append(self.env.now-tiempo[paciente])
        elif(tipo == 2):
            tipo_paciente='adolecente'
            #print('llega adolecente')
            yield self.env.timeout(random.uniform(0.025, 0.040) )
        elif(tipo == 3):
            tipo_paciente='adulto'
            #print('llega adulto')
            yield self.env.timeout(random.uniform(0.030, 0.055) )
        else:
            tipo_paciente='adulto mayor'
            #print('llega tercera edad')
            yield self.env.timeout(random.uniform(0.015, 0.030) )
            
        print("El paciente ", paciente, 'de tipo',tipo_paciente," fue atendido en : ", self.env.now-tiempo[paciente], "  en el hospital  ", self.name)
        
    def ingresar_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_INTERNADO-5, DIAS_INTERNADO+5))
        print("El paciente se termino de atender: ", paciente, " tiempo de salida: ", self.env.now, " hospital ", self.name)


    
    
    

def llegada_paciente(env, hospital, paciente):
    arrive = env.now
    atencion={}
    with hospital.consultorio.request() as consultorio:
        ##tipo de paciente 
        tipo= random.randint(1,4)
        #tiempo[paciente]=env.now+(random.uniform(0.000, 1))
        tiempo[paciente] = env.now

        print("Llega nuevo paciente  : ", paciente, " tipo: ",tipo,' en tiempo:', tiempo[paciente])
        requerimiento = yield consultorio | env.timeout(1)
        if consultorio in requerimiento:
            #print("Al paciente es atendido")
            atencion[paciente]='si'
            yield env.process(hospital.triaje(paciente,tipo,tiempo))

        else:
            atencion[paciente]='no'
            
            
           
            
            
    if(atencion[paciente]=='si') :
        estado = random.randint(1,100)
        if (estado < 60):
             with hospital.camas.request() as cama:
                    dias_esperando = random.randint(1,5)
                    requerimiento = yield cama | env.timeout(dias_esperando)
                    #print('\t paciente requiere diagnostico')
                    wait = env.now - arrive
                    if cama in requerimiento:
                        print("\t ee Al paciente: ", paciente, " se le asigna una CAMA ", " hospital " , hospital.name)
                        yield env.process(hospital.ingresar_paciente(paciente))
                        estado = random.randint(1,100)
                        if (estado < 8) :
                            persona_fallecidas[round(env.now)] = persona_fallecidas[round(env.now)] + 1 if env.now in persona_fallecidas else  1
                        else:
                            persona_recuperadas[round(env.now)] = persona_recuperadas[round(env.now)] + 1 if env.now in persona_recuperadas else 1
                    else:
                        print("\t ew El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait , " dias y fallece no hay camas")
                        persona_fallecidas[round(env.now)] = persona_fallecidas[round(env.now)] + 1 if env.now in persona_fallecidas else  1    
           
        else :
            print("\t El paciente ",paciente,"no tiene COVID.")
       
    else:
        personas_sin_atender.append(paciente)
        print('paciente :',paciente,'no fue atendido en el dia')

    
def ejecutar(env, tasa_crecimiento, infectados):
    hospitalA = Hospital(env, HOSPITAL_CAMA_A, "A",CONSULTORIO_HOSPITAL_A)
    hospitalB = Hospital(env, HOSPITAL_CAMA_B, "B",CONSULTORIO_HOSPITAL_B)
    for i in range(infectados):
        asignar_hospital(env, hospitalA, hospitalB, i)
    paciente = infectados
    while True:
        yield env.timeout(1)
        print('siguente dia',env.now)
        for i in range(tasa_crecimiento):
            paciente += 1
            asignar_hospital(env, hospitalA, hospitalB, paciente)

    
def asignar_hospital(env, hospitalA, hospitalB, paciente):
    hosp_esc = random.randint(1,2)

    if (hosp_esc == 1):
       
       # print("Llega paciente nuevo : ", paciente, " hospital A tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalA, paciente))
    else:
       # print("Llega paciente nuevo : ", paciente, " hospital B tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalB, paciente))
        

print("Simulacion COVID 19")
env=simpy.Environment()
env.process(ejecutar(env,TASA_CRECIMIENTO, INFECTADOS))
env.run(until=DIAS_SIMULACION)
print()

print("Resultados pacientes :")
print("Recuperados: ")
print(list(persona_recuperadas))
print("Fallecidos: ")
print(list(persona_fallecidas))

print('total pacientes sin atender',len(personas_sin_atender))


datos=sorted(persona_recuperadas.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor
tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  334  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  335  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  336  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  337  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  338  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  339  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  340  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  341  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  342  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  343  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  344  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  345  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  346  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  347  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  348  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  349  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  350  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  351  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  352  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  353  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  354  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  355  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  356  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  357  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  358  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  359  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  360  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  361  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  362  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  363  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  364  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  365  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  366  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  367  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  368  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  369  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  370  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  371  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  372  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  373  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  374  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  375  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  376  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  377  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  378  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  379  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  380  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  381  tipo:  4  en tiempo: 0
# Llega nuevo paciente  :  382  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  383  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  384  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  385  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  386  tipo:  1  en tiempo: 0
# Llega nuevo paciente  :  387  tipo:  3  en tiempo: 0
# Llega nuevo paciente  :  388  tipo:  2  en tiempo: 0
# Llega nuevo paciente  :  389  tipo:  3  en tiempo: 0
# consultorio disponible en el hospital  A
# consultorio disponible en el hospital  B
# consultorio disponible en el hospital  B
# consultorio disponible en el hospital  A
# consultorio disponible en el hospital  A
# consultorio disponible en el hospital  A
# consultorio disponible en el hospital  A
# consultorio disponible en el hospital  B
# El paciente  0 de tipo adulto mayor  fue atendido en :  0.0162789676252751   en el hospital   A
# paciente : 0 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3 de tipo niño  fue atendido en :  0.01905225665423223   en el hospital   A
# paciente : 3 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  5 de tipo niño  fue atendido en :  0.01946616938458909   en el hospital   A
# paciente : 5 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  6 de tipo niño  fue atendido en :  0.020759139228788817   en el hospital   A
# paciente : 6 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  8 de tipo niño  fue atendido en :  0.022489996316019667   en el hospital   B
# paciente : 8 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  4 de tipo adulto mayor  fue atendido en :  0.02333398273878242   en el hospital   A
# paciente : 4 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  1 de tipo niño  fue atendido en :  0.024429795663906607   en el hospital   B
# paciente : 1 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  2 de tipo adulto mayor  fue atendido en :  0.02530795533594743   en el hospital   B
# paciente : 2 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  9 de tipo niño  fue atendido en :  0.048767832213909595   en el hospital   B
# paciente : 9 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  16 de tipo adulto mayor  fue atendido en :  0.04890657539190154   en el hospital   A
# paciente : 16 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  15 de tipo niño  fue atendido en :  0.04907785908890151   en el hospital   A
# paciente : 15 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  17 de tipo niño  fue atendido en :  0.04933991574051708   en el hospital   A
# paciente : 17 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  7 de tipo adulto  fue atendido en :  0.049990056759604266   en el hospital   A
# paciente : 7 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  12 de tipo adulto  fue atendido en :  0.05280504240785644   en el hospital   A
# paciente : 12 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  11 de tipo adolecente  fue atendido en :  0.0640282245338869   en el hospital   B
# paciente : 11 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  22 de tipo adulto mayor  fue atendido en :  0.07106487977708438   en el hospital   A
# paciente : 22 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  10 de tipo adulto  fue atendido en :  0.07395539077644828   en el hospital   B
# paciente : 10 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  20 de tipo adulto mayor  fue atendido en :  0.07481294429321518   en el hospital   A
# paciente : 20 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  13 de tipo adulto mayor  fue atendido en :  0.07576813772040483   en el hospital   B
# paciente : 13 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  23 de tipo adolecente  fue atendido en :  0.07766841004055688   en el hospital   A
# paciente : 23 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  24 de tipo niño  fue atendido en :  0.0780648809126196   en el hospital   A
# paciente : 24 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  14 de tipo niño  fue atendido en :  0.0821468578218185   en el hospital   B
# paciente : 14 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  18 de tipo adolecente  fue atendido en :  0.08553391574288877   en el hospital   A
# paciente : 18 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente
no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  178 de tipo niño  fue atendido en :  0.4761928121528964   en el hospital   A
# paciente : 178 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  174 de tipo adulto  fue atendido en :  0.4773822810631185   en el hospital   A
# paciente : 174 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  177 de tipo adulto  fue atendido en :  0.4858190976401683   en el hospital   A
# paciente : 177 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  181 de tipo adulto mayor  fue atendido en :  0.49040232765369385   en el hospital   A
# paciente : 181 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  183 de tipo niño  fue atendido en :  0.49250974074451237   en el hospital   A
# paciente : 183 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  79 de tipo adolecente  fue atendido en :  0.49517773964354017   en el hospital   B
# paciente : 79 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  180 de tipo adulto  fue atendido en :  0.4965144832606162   en el hospital   A
# paciente : 180 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  81 de tipo adulto  fue atendido en :  0.4968451363883899   en el hospital   B
# paciente : 81 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  190 de tipo adulto mayor  fue atendido en :  0.5060804777502083   en el hospital   A
# paciente : 190 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  184 de tipo adulto  fue atendido en :  0.513332207539334   en el hospital   A
# paciente : 184 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  86 de tipo niño  fue atendido en :  0.5145902384962384   en el hospital   B
# paciente : 86 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  87 de tipo niño  fue atendido en :  0.5161906010692208   en el hospital   B
# paciente : 87 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  192 de tipo adolecente  fue atendido en :  0.5210113263853863   en el hospital   A
# paciente : 192 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  82 de tipo adulto  fue atendido en :  0.5264384340436119   en el hospital   B
# paciente : 82 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  188 de tipo adulto  fue atendido en :  0.5287414735346998   en el hospital   A
# paciente : 188 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  197 de tipo niño  fue atendido en :  0.5308371723064611   en el hospital   A
# paciente : 197 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  89 de tipo niño  fue atendido en :  0.535564645822665   en el hospital   B
# paciente : 89 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  196 de tipo adolecente  fue atendido en :  0.5413396424012706   en el hospital   A
# paciente : 196 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  88 de tipo adolecente  fue atendido en :  0.5432182703094394   en el hospital   B
# paciente : 88 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  195 de tipo adulto  fue atendido en :  0.5474033937069016   en el hospital   A
# paciente : 195 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  91 de tipo adulto mayor  fue atendido en :  0.551127600181393   en el hospital   B
# paciente : 91 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  90 de tipo adulto mayor  fue atendido en :  0.5547758711839105   en el hospital   B
# paciente : 90 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  199 de tipo adulto  fue atendido en :  0.5559384474830248   en el hospital   A
# paciente : 199 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  200 de tipo adolecente  fue atendido en :  0.5588293725982469   en el hospital   A
# paciente : 200 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  205 de tipo niño  fue atendido en :  0.5603432406820327   en el hospital   A
# paciente : 205 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  95 de tipo niño  fue atendido en :  0.5613672569063357   en el hospital   B
# paciente : 95 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  218 de tipo adulto mayor  fue atendido en :  0.562484512973518   en el hospital   A
# paciente : 218 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  203 de tipo adulto  fue atendido en :  0.5718085231008208   en el hospital   A
# paciente : 203 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  97 de tipo niño  fue atendido en :  0.5718313743642426   en el hospital   B
# paciente : 97 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  96 de tipo adolecente  fue atendido en :  0.5811467603468375   en el hospital   B
# paciente : 96 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  224 de tipo adolecente  fue atendido en :  0.5845777652943535   en el hospital   A
# paciente : 224 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  227 de tipo niño  fue atendido en :  0.5930131058364766   en el hospital   A
# paciente : 227 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  99 de tipo adolecente  fue atendido en :  0.5943235949311534   en el hospital   B
# ...
# consultorio disponible en el hospital  B
# El paciente  3087 de tipo adulto mayor  fue atendido en :  0.2178622490369797   en el hospital   A
# paciente : 3087 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3085 de tipo adulto mayor  fue atendido en :  0.21849758978696698   en el hospital   A
# paciente : 3085 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3040 de tipo adulto mayor  fue atendido en :  0.2219182799412387   en el hospital   B
# paciente : 3040 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3078 de tipo adulto  fue atendido en :  0.22591750063429217   en el hospital   A
# paciente : 3078 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3082 de tipo adulto  fue atendido en :  0.23054462558147293   en el hospital   A
# paciente : 3082 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3088 de tipo niño  fue atendido en :  0.2370554207760449   en el hospital   A
# paciente : 3088 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3093 de tipo adulto mayor  fue atendido en :  0.23859076149381409   en el hospital   A
# paciente : 3093 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3045 de tipo adolecente  fue atendido en :  0.24290054587617504   en el hospital   B
# paciente : 3045 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3041 de tipo adulto  fue atendido en :  0.2493794642897953   en el hospital   B
# paciente : 3041 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3095 de tipo adulto mayor  fue atendido en :  0.2529341013133397   en el hospital   A
# paciente : 3095 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3089 de tipo adolecente  fue atendido en :  0.25634160186451993   en el hospital   A
# paciente : 3089 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3047 de tipo niño  fue atendido en :  0.266851462271422   en el hospital   B
# paciente : 3047 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3046 de tipo adulto  fue atendido en :  0.2711202446158829   en el hospital   B
# paciente : 3046 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3099 de tipo adolecente  fue atendido en :  0.272315025705435   en el hospital   A
# paciente : 3099 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3100 de tipo adulto  fue atendido en :  0.27804480055209524   en el hospital   A
# paciente : 3100 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3096 de tipo adulto  fue atendido en :  0.2813961414259687   en el hospital   A
# paciente : 3096 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3049 de tipo adolecente  fue atendido en :  0.2821294441388922   en el hospital   B
# paciente : 3049 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3102 de tipo adulto  fue atendido en :  0.2921765315146274   en el hospital   A
# paciente : 3102 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3101 de tipo adulto  fue atendido en :  0.2929712640245121   en el hospital   A
# paciente : 3101 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3052 de tipo niño  fue atendido en :  0.296989480127376   en el hospital   B
# paciente : 3052 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3104 de tipo adulto mayor  fue atendido en :  0.3040004671400034   en el hospital   A
# paciente : 3104 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3105 de tipo niño  fue atendido en :  0.3055200014376034   en el hospital   A
# paciente : 3105 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3107 de tipo niño  fue atendido en :  0.3082434491176045   en el hospital   A
# paciente : 3107 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3103 de tipo adulto  fue atendido en :  0.3161126640541916   en el hospital   A
# paciente : 3103 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3053 de tipo adulto  fue atendido en :  0.31788025942777764   en el hospital   B
# paciente : 3053 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3051 de tipo adulto  fue atendido en :  0.3201655594126329   en el hospital   B
# paciente : 3051 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3106 de tipo adolecente  fue atendido en :  0.3212481296413294   en el hospital   A
# paciente : 3106 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3109 de tipo niño  fue atendido en :  0.3292267260170938   en el hospital   A
# paciente : 3109 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3054 de tipo adulto  fue atendido en :  0.32991751513212364   en el hospital   B
# paciente : 3054 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3119 de tipo niño  fue atendido en :  0.3309781715707807   en el hospital   A
# paciente : 3119 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  3055 de tipo adulto mayor  fue atendido en :  0.33499162139163374   en el hospital   B
# paciente : 3055 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3122 de tipo adulto mayor  fue atendido en :  0.3385631815929031   en el hospital   A
# paciente : 3122 no fue atendido en el dia
# consultorio disponible en el hospital  A
# El paciente  
no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3080 de tipo adolecente  fue atendido en :  0.46641439156543285   en el hospital   B
# paciente : 3080 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3083 de tipo niño  fue atendido en :  0.467719380169644   en el hospital   B
# paciente : 3083 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3091 de tipo adulto mayor  fue atendido en :  0.4833403696997358   en el hospital   B
# paciente : 3091 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3086 de tipo adolecente  fue atendido en :  0.4852539893837893   en el hospital   B
# paciente : 3086 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3090 de tipo adulto mayor  fue atendido en :  0.4934882494651447   en el hospital   B
# paciente : 3090 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3092 de tipo adolecente  fue atendido en :  0.5110831108064424   en el hospital   B
# paciente : 3092 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3097 de tipo niño  fue atendido en :  0.5145688513947455   en el hospital   B
# paciente : 3097 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3094 de tipo adolecente  fue atendido en :  0.5199608652557153   en el hospital   B
# paciente : 3094 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3098 de tipo niño  fue atendido en :  0.5264572038788202   en el hospital   B
# paciente : 3098 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3110 de tipo niño  fue atendido en :  0.539913568644927   en el hospital   B
# paciente : 3110 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3108 de tipo adulto mayor  fue atendido en :  0.542249334115187   en el hospital   B
# paciente : 3108 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3111 de tipo adulto mayor  fue atendido en :  0.5493088493950076   en el hospital   B
# paciente : 3111 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3114 de tipo adolecente  fue atendido en :  0.5812456039400047   en el hospital   B
# paciente : 3114 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3112 de tipo adulto  fue atendido en :  0.5904761288318703   en el hospital   B
# paciente : 3112 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3113 de tipo adulto  fue atendido en :  0.5922751671399098   en el hospital   B
# paciente : 3113 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3115 de tipo niño  fue atendido en :  0.6054841234014745   en el hospital   B
# paciente : 3115 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3117 de tipo niño  fue atendido en :  0.6199420342098492   en el hospital   B
# paciente : 3117 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3118 de tipo adolecente  fue atendido en :  0.632144804804593   en el hospital   B
# paciente : 3118 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3120 de tipo niño  fue atendido en :  0.6347298087630477   en el hospital   B
# paciente : 3120 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3126 de tipo adulto mayor  fue atendido en :  0.6561434989513764   en el hospital   B
# paciente : 3126 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3125 de tipo adolecente  fue atendido en :  0.6589369205623825   en el hospital   B
# paciente : 3125 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3129 de tipo niño  fue atendido en :  0.6644253653484569   en el hospital   B
# paciente : 3129 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3137 de tipo niño  fue atendido en :  0.6813243154703983   en el hospital   B
# paciente : 3137 no fue atendido en el dia
# consultorio disponible en el hospital  B
# El paciente  3135 de tipo adulto mayor  fue atendido en :  0.6832237672021755   en el hospital   B
# paciente : 3135 no fue atendido en el dia
# El paciente  3143 de tipo adulto mayor  fue atendido en :  0.6967533063852613   en el hospital   B
# paciente : 3143 no fue atendido en el dia
# El paciente  3141 de tipo adolecente  fue atendido en :  0.7015114530054376   en el hospital   B
# paciente : 3141 no fue atendido en el dia
#
# Resultados pacientes :
# Recuperados:
# []
# Fallecidos:
# []
# total pacientes sin atender 3145
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-9c12de6caedc> in <module>
#     156
#     157 datos=sorted(persona_recuperadas.items()) # Ordenamos los datos
# --> 158 x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
#     159
#     160 pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %% [markdown]
# ## Referencias
# [1] Matloff, N. (2008). Introduction to Discrete-Event Simulation and the SimPy Language.
#
# [2] Team Simpy (2017). SimPy Documentation, Release 3.0.10, 2017. URL: https://media.readthedocs.org/pdf/simpy/latest/simpy.pdf
