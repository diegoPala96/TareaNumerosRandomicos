# %% [markdown]
# # Probabilidad y Estadística con Python

# %% [markdown]
# ## ¿Qué es la Estadística?
#
# La estadística suele ser definida como la ciencia de aprender de los datos o como la ciencia de obtener conclusiones en la presencia de incertidumbre. Se relaciona principalmente con la recolección, análisis e interpretación de datos, así como también con la efectiva comunicación y presentación de los resultados basados en esos datos. Como por datos entendemos a cualquier clase de información grabada, la estadística juego un rol importante en muchas disciplinas científicas.
#
# La estadística suele ser dividida en dos grandes ramas:
#
# La estadística descriptiva: La cual se dedica a recolectar, ordenar, analizar y representar a un conjunto de datos, con el fin de describir apropiadamente las características de este. Calcula los parámetros estadísticos que describen el conjunto estudiado. Algunas de las herramientas que utiliza son gráficos, medidas de frecuencias, medidas de centralización, medidas de posición, medidas de dispersión, entre otras.
#
# La estadistica inferencial: La cual estudia cómo sacar conclusiones generales para toda la población a partir del estudio de una muestra, y el grado de fiabilidad o significación de los resultados obtenidos. Sus principales herramientas son el muestreo, la estimación de parámetros y el contraste de hipótesis.

# %% [markdown]
# ## Conceptos básicos de la estadística descriptiva
#
# En *[estadística descriptiva](https://es.wikipedia.org/wiki/Estad%C3%ADstica_descriptiva)* se utilizan distintas medidas para intentar describir las propiedades de nuestros datos, algunos de los conceptos básicos, son:
#
# * **Media aritmética**: La [media aritmética](https://es.wikipedia.org/wiki/Media_aritm%C3%A9tica) es el valor obtenido al sumar todos los *[datos](https://es.wikipedia.org/wiki/Dato)* y dividir el resultado entre el número total elementos. Se suele representar con la letra griega $\mu$. Si tenemos una [muestra](https://es.wikipedia.org/wiki/Muestra_estad%C3%ADstica) de $n$ valores, $x_i$, la *media aritmética*, $\mu$, es la suma de los valores divididos por el numero de elementos; en otras palabras:
# $$\mu = \frac{1}{n} \sum_{i}x_i$$
#
#
# * **Desviación respecto a la media**: La desviación respecto a la media es la diferencia en valor absoluto entre cada valor de la variable estadística y la media aritmética.
# $$D_i = |x_i - \mu|$$
#
#
# * **Varianza**: La [varianza](https://es.wikipedia.org/wiki/Varianza) es la media aritmética del cuadrado de las desviaciones respecto a la media de una distribución estadística. La varianza intenta describir la dispersión de los *[datos](https://es.wikipedia.org/wiki/Dato)*. Se representa como $\sigma^2$.
# $$\sigma^2 = \frac{\sum\limits_{i=1}^n(x_i - \mu)^2}{n} $$
#
#
# * **Desviación típica**: La [desviación típica](https://es.wikipedia.org/wiki/Desviaci%C3%B3n_t%C3%ADpica) es la raíz cuadrada de la varianza. Se representa con la letra griega $\sigma$.
# $$\sigma = \sqrt{\frac{\sum\limits_{i=1}^n(x_i - \mu)^2}{n}} $$
#
#
# * **Moda**: La <a href="https://es.wikipedia.org/wiki/Moda_(estad%C3%ADstica)">moda</a> es el valor que tiene mayor frecuencia absoluta. Se representa con $M_0$
#
#
# * **Mediana**: La <a href="https://es.wikipedia.org/wiki/Mediana_(estad%C3%ADstica)">mediana</a> es el valor que ocupa el lugar central de todos los datos cuando éstos están ordenados de menor a mayor. Se representa con $\widetilde{x}$.

# %% [markdown]
# ### Ejemplos en Python
#
# Calcular los principales indicadores de la *[estadística descriptiva](https://es.wikipedia.org/wiki/Estad%C3%ADstica_descriptiva)* con [Python](http://python.org/) es muy fácil!.

# %% [markdown]
# ## Practica :
# Generar un modelo que me permita simular el uso de recursos de los hospitales por cada una de las provincias, para ello obtener la informacion revisada en la practica de investigacion y tomar como ejemplo la practica de simulacion de atencion de paciente del COVID revisada en clase. Lo que se busca es poder generar graficos de uso de recursos:
#
# - Costos (Generar un aproximacion de cuanto se invierte para atender a un paciente con COVID)
# - Personal (Aproximacion del uso del personal por paciente, o el hospital)
# - Camas
# - Equipos/Insumos medicos (Obtener una aproximacion del uso de equipos medicos)
# - Pacientes (Informacion obtenida desde el ministerio de salud - validar con el porcentual del tipo de paciente [ninio 10%, adulto 30%, riesgo 60%]) - Hospitalizacion 80%, Otros 20%
#
#
# Para ello deberan generar un modelo lo mas cercano a la realidad, y con ayuda de la estadistica descriptiva ajustar los valores. Es importante tener como datos de entrada el dia y el numero de pacientes.
#
# Finalmente validar el modelo con lo la realidad del pais (Investigar en  base al tema el uso de los recursos publicos )

# %%
import simpy 
import random
import numpy as np

import matplotlib.pyplot as pp
# %matplotlib inline

#PARAMETROS

TASA_CRECIMIENTO=137
INFECTADOS=390
HOSPITAL_CAMA=106 #HOSPITAL MARTIN ICAZA 106 total ocupadas regularmente 71
RESPIRADORES = 7
TESTS = 50

# %%
import simpy
import random
import matplotlib.pyplot as pp



PRECIO_TEST = [30, 50]
PERSONAL_MEDIDO = 30
#CAMAS = 20
RESPIRADORES = 7
TESTS = 50
TIEMPO_TEST_RAPIDO = 0.10

costos_totales = []
personas_test = []

res_usados = []
cam_usadas = []
per_res = []
per_cam = []


class Paciente:
   
    
    estado = False

    def __init__(self, nombre, estado):
        self.nombre = nombre
       
        self.estado = estado
class Hospital:
    camas = 0
    respiradores = 0

    
    camas = 0
    respiradores = 0
    def __init__(self, enviroment, num_camas, num_test, num_respiradores):
        self.enviroment = enviroment
        self.camas = simpy.Resource(enviroment, num_camas)
        self.test = simpy.Resource(enviroment, num_test)
        self.respirador = simpy.Resource(enviroment, num_respiradores)
        self.ncamas = HOSPITAL_CAMA
        self.nrespiradores = 7
    def realizar_test(self, paciente):
        paciente.test = True
        yield self.enviroment.timeout(TIEMPO_TEST_RAPIDO)
        p = random.randint(1, 100)
      
        
        precio = random.randint(30,50)
        
        print('El costo del Test es de:', precio)
        if  p > 50:
            print('Paciente', paciente.nombre, 'presenta COVIS-19, pero es necesario hospitalizacion')
            #per_cam[paciente]=1
            per_cam.append(1)
            self.ncamas -= 1
            cam_usadas.append(self.ncamas)
            print('CAMAS DISPONIBLES', self.ncamas)
            paciente.estado = True
        else:
            print('Paciente', paciente.nombre, 'presenta COVIS-19, pero NO es necesario hospitalizacion')
            paciente.estado = False
            #validar si es + o -
        costos_totales.append(precio)
        personas_test.append(1)
    def zona_aislamiento(self, paciente):
            paciente.atencion = True
            t = random.randint(1, 20)
            if t <= 16:
                yield self.enviroment.timeout(t)
                self.ncamas += 1
                cam_usadas.append(self.ncamas)
               
                
                print('El paciente', paciente.nombre, 'termina su recuperacion en', t)
            else:
                print('El paciente', paciente.nombre, 'fallece')
    

def llegada_paciente(enviroment, paciente, hospital):
    
    print('Llega el paciente: %s a la hora %.2f' %(paciente.nombre, enviroment.now))
    
    with hospital.test.request() as test:
        yield test
        print('El paciente', paciente.nombre, 'se realiza el test a la Hora: ',enviroment.now)
        yield enviroment.process(hospital.realizar_test(paciente))
        
    if paciente.estado:
            with hospital.camas.request() as cama:
                yield cama
                print(paciente.nombre,' se le asigna a una cama', enviroment.now)
                yield enviroment.process(hospital.zona_aislamiento(paciente))
                respirador = random.randint(1, 10)
                if respirador%2 == 0:
                    with hospital.respirador.request() as resp:
                        yield resp
                        print(paciente.nombre,' se le asigna a un respirador', enviroment.now)
                        per_res.append(paciente.nombre)
                        hospital.nrespiradores -= 1
                        res_usados.append(hospital.nrespiradores)
                        print('RESPIRADORES DISPONIBLES', hospital.nrespiradores)
    for x in per_res:
        if (x ==paciente.nombre):
            hospital.nrespiradores += 1
            res_usados.append(hospital.nrespiradores)
            print('incrementa respirados')
       # print(x,'xesiguala',paciente.nombre)
        


def ejecutar(enviroment, num_camas, num_test, num_respitadores):
    hospital = Hospital(enviroment, num_camas, num_test, num_respitadores)
    for i in range(1,10):
        edad = random.randint(5, 65)
        paciente = Paciente('paciente(%d)'% i, False)
        enviroment.process(llegada_paciente(enviroment, paciente, hospital))
        

        paciente = None
        
    while True:
        yield enviroment.timeout(1)
        edad = random.randint(5, 65)
        i += 1
        paciente = Paciente('paciente(%d)'% i, False)
        enviroment.process(llegada_paciente(enviroment, paciente, hospital))
        paciente = None
enviroment=simpy.Environment()
enviroment.process(ejecutar(enviroment, HOSPITAL_CAMA, TESTS, RESPIRADORES))
enviroment.run(until = 50)
print(costos_totales, 'costos totales')
media = sum(costos_totales)/len(costos_totales)
print('MEDIA ',media)
for i in range(len(personas_test)):
    personas_test[i] = i + 1
pp.plot(personas_test, costos_totales)
pp.title('Persona - Costos')
pp.ylabel('$ Precio')
pp.xlabel('Personas')
pp.show()
# Out:
# Llega el paciente: paciente(1) a la hora 0.00
# Llega el paciente: paciente(2) a la hora 0.00
# Llega el paciente: paciente(3) a la hora 0.00
# Llega el paciente: paciente(4) a la hora 0.00
# Llega el paciente: paciente(5) a la hora 0.00
# Llega el paciente: paciente(6) a la hora 0.00
# Llega el paciente: paciente(7) a la hora 0.00
# Llega el paciente: paciente(8) a la hora 0.00
# Llega el paciente: paciente(9) a la hora 0.00
# El paciente paciente(1) se realiza el test a la Hora:  0
# El paciente paciente(2) se realiza el test a la Hora:  0
# El paciente paciente(3) se realiza el test a la Hora:  0
# El paciente paciente(4) se realiza el test a la Hora:  0
# El paciente paciente(5) se realiza el test a la Hora:  0
# El paciente paciente(6) se realiza el test a la Hora:  0
# El paciente paciente(7) se realiza el test a la Hora:  0
# El paciente paciente(8) se realiza el test a la Hora:  0
# El paciente paciente(9) se realiza el test a la Hora:  0
# El costo del Test es de: 34
# Paciente paciente(1) presenta COVIS-19, pero NO es necesario hospitalizacion
# El costo del Test es de: 42
# Paciente paciente(2) presenta COVIS-19, pero NO es necesario hospitalizacion
# El costo del Test es de: 39
# Paciente paciente(3) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 105
# El costo del Test es de: 48
# Paciente paciente(4) presenta COVIS-19, pero NO es necesario hospitalizacion
# El costo del Test es de: 47
# Paciente paciente(5) presenta COVIS-19, pero NO es necesario hospitalizacion
# El costo del Test es de: 47
# Paciente paciente(6) presenta COVIS-19, pero NO es necesario hospitalizacion
# El costo del Test es de: 47
# Paciente paciente(7) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 104
# El costo del Test es de: 49
# Paciente paciente(8) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 103
# El costo del Test es de: 30
# Paciente paciente(9) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 102
# paciente(3)  se le asigna a una cama 0.1
# El paciente paciente(3) fallece
# paciente(7)  se le asigna a una cama 0.1
# paciente(8)  se le asigna a una cama 0.1
# paciente(9)  se le asigna a una cama 0.1
# paciente(3)  se le asigna a un respirador 0.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# Llega el paciente: paciente(10) a la hora 1.00
# El paciente paciente(10) se realiza el test a la Hora:  1
# El costo del Test es de: 36
# Paciente paciente(10) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(11) a la hora 2.00
# El paciente paciente(11) se realiza el test a la Hora:  2
# El costo del Test es de: 36
# Paciente paciente(11) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 101
# paciente(11)  se le asigna a una cama 2.1
# Llega el paciente: paciente(12) a la hora 3.00
# El paciente paciente(12) se realiza el test a la Hora:  3
# El paciente paciente(7) termina su recuperacion en 3
# El costo del Test es de: 41
# Paciente paciente(12) presenta COVIS-19, pero NO es necesario hospitalizacion
# paciente(7)  se le asigna a un respirador 3.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# Llega el paciente: paciente(13) a la hora 4.00
# El paciente paciente(13) se realiza el test a la Hora:  4
# El costo del Test es de: 47
# Paciente paciente(13) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 101
# paciente(13)  se le asigna a una cama 4.1
# Llega el paciente: paciente(14) a la hora 5.00
# El paciente paciente(14) se realiza el test a la Hora:  5
# El costo del Test es de: 31
# Paciente paciente(14) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(15) a la hora 6.00
# El paciente paciente(15) se realiza el test a la Hora:  6
# El costo del Test es de: 39
# Paciente paciente(15) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(16) a la hora 7.00
# El paciente paciente(16) se realiza el test a la Hora:  7
# El costo del Test es de: 37
# Paciente paciente(16) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(17) a la hora 8.00
# El paciente paciente(17) se realiza el test a la Hora:  8
# El paciente paciente(9) termina su recuperacion en 8
# El costo del Test es de: 32
# Paciente paciente(17) presenta COVIS-19, pero NO es necesario hospitalizacion
# paciente(9)  se le asigna a un respirador 8.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# Llega el paciente: paciente(18) a la hora 9.00
# El paciente paciente(18) se realiza el test a la Hora:  9
# El costo del Test es de: 40
# Paciente paciente(18) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 101
# paciente(18)  se le asigna a una cama 9.1
# El paciente paciente(18) fallece
# Llega el paciente: paciente(19) a la hora 10.00
# El paciente paciente(19) se realiza el test a la Hora:  10
# El costo del Test es de: 39
# Paciente paciente(19) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(20) a la hora 11.00
# El paciente paciente(20) se realiza el test a la Hora:  11
# El paciente paciente(8) termina su recuperacion en 11
# El paciente paciente(11) termina su recuperacion en 9
# El costo del Test es de: 34
# Paciente paciente(20) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(21) a la hora 12.00
# El paciente paciente(21) se realiza el test a la Hora:  12
# El costo del Test es de: 37
# Paciente paciente(21) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 102
# paciente(21)  se le asigna a una cama 12.1
# Llega el paciente: paciente(22) a la hora 13.00
# El paciente paciente(22) se realiza el test a la Hora:  13
# El costo del Test es de: 42
# Paciente paciente(22) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 101
# paciente(22)  se le asigna a una cama 13.1
# Llega el paciente: paciente(23) a la hora 14.00
# El paciente paciente(23) se realiza el test a la Hora:  14
# El paciente paciente(22) termina su recuperacion en 1
# El costo del Test es de: 48
# Paciente paciente(23) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(24) a la hora 15.00
# El paciente paciente(24) se realiza el test a la Hora:  15
# El costo del Test es de: 37
# Paciente paciente(24) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(25) a la hora 16.00
# El paciente paciente(25) se realiza el test a la Hora:  16
# El paciente paciente(13) termina su recuperacion en 12
# El costo del Test es de: 48
# Paciente paciente(25) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 102
# paciente(25)  se le asigna a una cama 16.1
# Llega el paciente: paciente(26) a la hora 17.00
# El paciente paciente(26) se realiza el test a la Hora:  17
# El costo del Test es de: 34
# Paciente paciente(26) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 101
# paciente(26)  se le asigna a una cama 17.1
# Llega el paciente: paciente(27) a la hora 18.00
# El paciente paciente(27) se realiza el test a la Hora:  18
# El costo del Test es de: 30
# Paciente paciente(27) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 100
# paciente(27)  se le asigna a una cama 18.1
# Llega el paciente: paciente(28) a la hora 19.00
# El paciente paciente(28) se realiza el test a la Hora:  19
# El costo del Test es de: 32
# Paciente paciente(28) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 99
# paciente(28)  se le asigna a una cama 19.1
# Llega el paciente: paciente(29) a la hora 20.00
# El paciente paciente(29) se realiza el test a la Hora:  20
# El costo del Test es de: 39
# Paciente paciente(29) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(30) a la hora 21.00
# El paciente paciente(30) se realiza el test a la Hora:  21
# El paciente paciente(25) termina su recuperacion en 5
# El costo del Test es de: 45
# Paciente paciente(30) presenta COVIS-19, pero NO es necesario hospitalizacion
# paciente(25)  se le asigna a un respirador 21.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# Llega el paciente: paciente(31) a la hora 22.00
# El paciente paciente(31) se realiza el test a la Hora:  22
# El paciente paciente(21) termina su recuperacion en 10
# El costo del Test es de: 36
# Paciente paciente(31) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 100
# paciente(21)  se le asigna a un respirador 22.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# paciente(31)  se le asigna a una cama 22.1
# Llega el paciente: paciente(32) a la hora 23.00
# El paciente paciente(32) se realiza el test a la Hora:  23
# El costo del Test es de: 33
# Paciente paciente(32) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 99
# paciente(32)  se le asigna a una cama 23.1
# Llega el paciente: paciente(33) a la hora 24.00
# El paciente paciente(33) se realiza el test a la Hora:  24
# El paciente paciente(26) termina su recuperacion en 7
# El paciente paciente(27) termina su recuperacion en 6
# El costo del Test es de: 49
# Paciente paciente(33) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(34) a la hora 25.00
# El paciente paciente(34) se realiza el test a la Hora:  25
# El costo del Test es de: 39
# Paciente paciente(34) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(35) a la hora 26.00
# El paciente paciente(35) se realiza el test a la Hora:  26
# El costo del Test es de: 50
# Paciente paciente(35) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(36) a la hora 27.00
# El paciente paciente(36) se realiza el test a la Hora:  27
# El paciente paciente(32) termina su recuperacion en 4
# El costo del Test es de: 41
# Paciente paciente(36) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(37) a la hora 28.00
# El paciente paciente(37) se realiza el test a la Hora:  28
# El costo del Test es de: 32
# Paciente paciente(37) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(38) a la hora 29.00
# El paciente paciente(38) se realiza el test a la Hora:  29
# El costo del Test es de: 34
# Paciente paciente(38) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(39) a la hora 30.00
# El paciente paciente(39) se realiza el test a la Hora:  30
# El paciente paciente(31) termina su recuperacion en 8
# El costo del Test es de: 39
# Paciente paciente(39) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 102
# paciente(39)  se le asigna a una cama 30.1
# Llega el paciente: paciente(40) a la hora 31.00
# El paciente paciente(40) se realiza el test a la Hora:  31
# El costo del Test es de: 35
# Paciente paciente(40) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 101
# paciente(40)  se le asigna a una cama 31.1
# Llega el paciente: paciente(41) a la hora 32.00
# El paciente paciente(41) se realiza el test a la Hora:  32
# El costo del Test es de: 33
# Paciente paciente(41) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 100
# paciente(41)  se le asigna a una cama 32.1
# Llega el paciente: paciente(42) a la hora 33.00
# El paciente paciente(42) se realiza el test a la Hora:  33
# El paciente paciente(28) termina su recuperacion en 14
# El costo del Test es de: 46
# Paciente paciente(42) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 100
# paciente(28)  se le asigna a un respirador 33.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# paciente(42)  se le asigna a una cama 33.1
# El paciente paciente(42) fallece
# paciente(42)  se le asigna a un respirador 33.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# Llega el paciente: paciente(43) a la hora 34.00
# El paciente paciente(43) se realiza el test a la Hora:  34
# El costo del Test es de: 47
# Paciente paciente(43) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(44) a la hora 35.00
# El paciente paciente(44) se realiza el test a la Hora:  35
# El costo del Test es de: 30
# Paciente paciente(44) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(45) a la hora 36.00
# El paciente paciente(45) se realiza el test a la Hora:  36
# El costo del Test es de: 46
# Paciente paciente(45) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 99
# paciente(45)  se le asigna a una cama 36.1
# Llega el paciente: paciente(46) a la hora 37.00
# El paciente paciente(46) se realiza el test a la Hora:  37
# El costo del Test es de: 41
# Paciente paciente(46) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(47) a la hora 38.00
# El paciente paciente(47) se realiza el test a la Hora:  38
# El costo del Test es de: 31
# Paciente paciente(47) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 98
# paciente(47)  se le asigna a una cama 38.1
# Llega el paciente: paciente(48) a la hora 39.00
# El paciente paciente(48) se realiza el test a la Hora:  39
# El paciente paciente(40) termina su recuperacion en 8
# El paciente paciente(47) termina su recuperacion en 1
# El costo del Test es de: 37
# Paciente paciente(48) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 99
# paciente(40)  se le asigna a un respirador 39.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# paciente(47)  se le asigna a un respirador 39.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# paciente(48)  se le asigna a una cama 39.1
# Llega el paciente: paciente(49) a la hora 40.00
# El paciente paciente(49) se realiza el test a la Hora:  40
# El paciente paciente(45) termina su recuperacion en 4
# El costo del Test es de: 36
# Paciente paciente(49) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(50) a la hora 41.00
# El paciente paciente(50) se realiza el test a la Hora:  41
# El costo del Test es de: 30
# Paciente paciente(50) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 99
# paciente(50)  se le asigna a una cama 41.1
# El paciente paciente(50) fallece
# paciente(50)  se le asigna a un respirador 41.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# Llega el paciente: paciente(51) a la hora 42.00
# El paciente paciente(51) se realiza el test a la Hora:  42
# El costo del Test es de: 50
# Paciente paciente(51) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 98
# paciente(51)  se le asigna a una cama 42.1
# Llega el paciente: paciente(52) a la hora 43.00
# El paciente paciente(52) se realiza el test a la Hora:  43
# El paciente paciente(39) termina su recuperacion en 13
# El paciente paciente(41) termina su recuperacion en 11
# El costo del Test es de: 31
# Paciente paciente(52) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 99
# paciente(52)  se le asigna a una cama 43.1
# Llega el paciente: paciente(53) a la hora 44.00
# El paciente paciente(53) se realiza el test a la Hora:  44
# El costo del Test es de: 35
# Paciente paciente(53) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(54) a la hora 45.00
# El paciente paciente(54) se realiza el test a la Hora:  45
# El costo del Test es de: 45
# Paciente paciente(54) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(55) a la hora 46.00
# El paciente paciente(55) se realiza el test a la Hora:  46
# El costo del Test es de: 49
# Paciente paciente(55) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 98
# paciente(55)  se le asigna a una cama 46.1
# Llega el paciente: paciente(56) a la hora 47.00
# El paciente paciente(56) se realiza el test a la Hora:  47
# El costo del Test es de: 50
# Paciente paciente(56) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 97
# paciente(56)  se le asigna a una cama 47.1
# Llega el paciente: paciente(57) a la hora 48.00
# El paciente paciente(57) se realiza el test a la Hora:  48
# El costo del Test es de: 44
# Paciente paciente(57) presenta COVIS-19, pero NO es necesario hospitalizacion
# Llega el paciente: paciente(58) a la hora 49.00
# El paciente paciente(58) se realiza el test a la Hora:  49
# El paciente paciente(55) termina su recuperacion en 3
# El paciente paciente(56) termina su recuperacion en 2
# El costo del Test es de: 47
# Paciente paciente(58) presenta COVIS-19, pero es necesario hospitalizacion
# CAMAS DISPONIBLES 98
# paciente(55)  se le asigna a un respirador 49.1
# RESPIRADORES DISPONIBLES 6
# incrementa respirados
# paciente(58)  se le asigna a una cama 49.1
# [34, 42, 39, 48, 47, 47, 47, 49, 30, 36, 36, 41, 47, 31, 39, 37, 32, 40, 39, 34, 37, 42, 48, 37, 48, 34, 30, 32, 39, 45, 36, 33, 49, 39, 50, 41, 32, 34, 39, 35, 33, 46, 47, 30, 46, 41, 31, 37, 36, 30, 50, 31, 35, 45, 49, 50, 44, 47] costos totales
# MEDIA  39.706896551724135

# %%
pp.plot([i for i in range(len(res_usados))], res_usados)
pp.title('Respiradores')
pp.show()

# %%
pp.plot([i for i in range(len(cam_usadas))], cam_usadas)
pp.title('Camas Usadas')
pp.show()

# %% [markdown]
# ## Conclusiones
#
# podemos observar como es el uso de los recursos dentro de un hospital y los costos de personas por cada una de las pruebas que se reallizan en la diferentes faces
# ## Recomendaciones
# tener una informacion mas detallada de los procesos, recurso,implemento y tiempo por persona, de las personas que tiene covid y como el personal se hace cargo en las diferentes etapas que se presentra dentro del hospital
#
#
# ## Opiniones
